# %% [markdown]
# COMP 215 - LAB 3 Classes (NEO)
# ----------------
# #### Name: Serena Harrington
# #### Date: 20/01/2026
#
# This lab exercise introduces `class` as a means of organizing related data and functions.
#
# **Building on new concepts from lab 2**:
#   * a `record` is a related collection of data, with fields for each data value
#   * an `API` is an "Application Programmers Interface" defining how a programmer interacts with a system.
#   * *f-string* simplifies string formatting operations
#
# **New Python Concepts**:
#   * the `class` keyword allows you define a new data `type`, with a set of operations on that data.
#   * a `dataclass` simplifies class definition for classes that primarily encapsulate a data structure.
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from datetime import datetime
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# We'll continue working with [Near Earth Object](https://cneos.jpl.nasa.gov/) data
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# Here's a brief review from Lab 2 on how to use it...

# %% [markdown]
# ### Review: making a query
#
# Here's a query that gets the record for a single NEO that recently passed by.

# %%
API_KEY = 'DEMO_KEY'  # substitute your API key here

def get_neos(start_date):
    """ Return a list of NEO for the week starting at start_date """
    url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={start_date}&api_key={API_KEY}'
    # Fetch last week's NEO feed
    response = requests.request("GET", url, headers={}, data={})
    data = json.loads(response.text)
    return [neo for dated_records in data['near_earth_objects'].values() for neo in dated_records ]

def get_neo(id):
    """ Return a NEO record for the given id """
    url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}?api_key={API_KEY}'
    response = requests.request("GET", url, headers={}, data={})
    return json.loads(response.text)

# Sample usage:  get the list of NEOs for a given week, then lookup the latest NEO record in that list.
week_start = '2023-01-15'
neos = get_neos(week_start)
print(f'{len(neos)} Near Earth Objects found for week of {week_start}')
assert len(neos) > 0, f'Oh oh!  No NEOs found for {week_start}'
neo = get_neo(neos[-1]['id'])  # get the very latest NEO
pprint(neo)
# Out:
# 13 Near Earth Objects found for week of 2023-01-15
# {'absolute_magnitude_h': 27.9,
#  'close_approach_data': [{'close_approach_date': '1963-10-03',
#                           'close_approach_date_full': '1963-Oct-03 10:42',
#                           'epoch_date_close_approach': -197126280000,
#                           'miss_distance': {'astronomical': '0.0314084333',
#                                             'kilometers': '4698634.721717071',
#                                             'lunar': '12.2178805537',
#                                             'miles': '2919596.2325987398'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '52882.6650360426',
#                                                 'kilometers_per_second': '14.6896291767',
#                                                 'miles_per_hour': '32859.2315053121'}},
#                          {'close_approach_date': '1966-10-20',
#                           'close_approach_date_full': '1966-Oct-20 01:27',
#                           'epoch_date_close_approach': -100996380000,
#                           'miss_distance': {'astronomical': '0.0938973021',
#                                             'kilometers': '14046836.392906527',
#                                             'lunar': '36.5260505169',
#                                             'miles': '8728299.3979309926'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '60656.1194589548',
#                                                 'kilometers_per_second': '16.8489220719',
#                                                 'miles_per_hour': '37689.3537827045'}},
#                          {'close_approach_date': '1970-06-06',
#                           'close_approach_date_full': '1970-Jun-06 13:47',
#                           'epoch_date_close_approach': 13528020000,
#                           'miss_distance': {'astronomical': '0.1023289464',
#                                             'kilometers': '15308192.420784168',
#                                             'lunar': '39.8059601496',
#                                             'miles': '9512069.6897427984'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '60340.298334647',
#                                                 'kilometers_per_second': '16.7611939818',
#                                                 'miles_per_hour': '37493.1148179922'}},
#                          {'close_approach_date': '1974-07-27',
#                           'close_approach_date_full': '1974-Jul-27 10:58',
#                           'epoch_date_close_approach': 144154680000,
#                           'miss_distance': {'astronomical': '0.1230616624',
#                                             'kilometers': '18409762.573699088',
#                                             'lunar': '47.8709866736',
#                                             'miles': '11439296.0160918944'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '73890.9216299545',
#                                                 'kilometers_per_second': '20.5252560083',
#                                                 'miles_per_hour': '45912.9451650126'}},
#                          {'close_approach_date': '1977-10-15',
#                           'close_approach_date_full': '1977-Oct-15 13:09',
#                           'epoch_date_close_approach': 245768940000,
#                           'miss_distance': {'astronomical': '0.1965217913',
#                                             'kilometers': '29399241.387064531',
#                                             'lunar': '76.4469768157',
#                                             'miles': '18267841.5068552878'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71839.4231161696',
#                                                 'kilometers_per_second': '19.95539531',
#                                                 'miles_per_hour': '44638.2237690444'}},
#                          {'close_approach_date': '1978-10-01',
#                           'close_approach_date_full': '1978-Oct-01 04:22',
#                           'epoch_date_close_approach': 276063720000,
#                           'miss_distance': {'astronomical': '0.3663835508',
#                                             'kilometers': '54810198.802716796',
#                                             'lunar': '142.5232012612',
#                                             'miles': '34057478.2697559448'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '34640.0575387996',
#                                                 'kilometers_per_second': '9.6222382052',
#                                                 'miles_per_hour': '21523.9846412613'}},
#                          {'close_approach_date': '1978-12-25',
#                           'close_approach_date_full': '1978-Dec-25 13:44',
#                           'epoch_date_close_approach': 283441440000,
#                           'miss_distance': {'astronomical': '0.3525872392',
#                                             'kilometers': '52746299.973500504',
#                                             'lunar': '137.1564360488',
#                                             'miles': '32775031.0051507952'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '46427.2023163381',
#                                                 'kilometers_per_second': '12.8964450879',
#                                                 'miles_per_hour': '28848.0580170602'}},
#                          {'close_approach_date': '1979-02-17',
#                           'close_approach_date_full': '1979-Feb-17 16:29',
#                           'epoch_date_close_approach': 288116940000,
#                           'miss_distance': {'astronomical': '0.0378277708',
#                                             'kilometers': '5658953.938528196',
#                                             'lunar': '14.7150028412',
#                                             'miles': '3516310.9238972648'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '49637.1518246578',
#                                                 'kilometers_per_second': '13.7880977291',
#                                                 'miles_per_hour': '30842.5958101603'}},
#                          {'close_approach_date': '1980-03-05',
#                           'close_approach_date_full': '1980-Mar-05 19:19',
#                           'epoch_date_close_approach': 321131940000,
#                           'miss_distance': {'astronomical': '0.4031066987',
#                                             'kilometers': '60303903.508251769',
#                                             'lunar': '156.8085057943',
#                                             'miles': '37471108.0816576522'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '58640.6656736507',
#                                                 'kilometers_per_second': '16.2890737982',
#                                                 'miles_per_hour': '36437.0291792748'}},
#                          {'close_approach_date': '1980-07-12',
#                           'close_approach_date_full': '1980-Jul-12 08:35',
#                           'epoch_date_close_approach': 332238900000,
#                           'miss_distance': {'astronomical': '0.4659876821',
#                                             'kilometers': '69710764.688397127',
#                                             'lunar': '181.2692083369',
#                                             'miles': '43316260.5756772726'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '38616.0940900145',
#                                                 'kilometers_per_second': '10.7266928028',
#                                                 'miles_per_hour': '23994.5391305426'}},
#                          {'close_approach_date': '1981-06-02',
#                           'close_approach_date_full': '1981-Jun-02 00:29',
#                           'epoch_date_close_approach': 360289740000,
#                           'miss_distance': {'astronomical': '0.0456437509',
#                                             'kilometers': '6828207.913450583',
#                                             'lunar': '17.7554191001',
#                                             'miles': '4242851.6537727254'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '49214.5982123483',
#                                                 'kilometers_per_second': '13.6707217257',
#                                                 'miles_per_hour': '30580.0374281116'}},
#                          {'close_approach_date': '1988-10-09',
#                           'close_approach_date_full': '1988-Oct-09 10:12',
#                           'epoch_date_close_approach': 592395120000,
#                           'miss_distance': {'astronomical': '0.3286101178',
#                                             'kilometers': '49159373.683329086',
#                                             'lunar': '127.8293358242',
#                                             'miles': '30546218.3598539468'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '86422.0920881821',
#                                                 'kilometers_per_second': '24.0061366912',
#                                                 'miles_per_hour': '53699.3271644596'}},
#                          {'close_approach_date': '1991-02-19',
#                           'close_approach_date_full': '1991-Feb-19 02:21',
#                           'epoch_date_close_approach': 666930060000,
#                           'miss_distance': {'astronomical': '0.416479098',
#                                             'kilometers': '62304385.96032126',
#                                             'lunar': '162.010369122',
#                                             'miles': '38714150.236742988'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62417.4007378046',
#                                                 'kilometers_per_second': '17.3381668716',
#                                                 'miles_per_hour': '38783.7454751098'}},
#                          {'close_approach_date': '1992-05-28',
#                           'close_approach_date_full': '1992-May-28 08:03',
#                           'epoch_date_close_approach': 707040180000,
#                           'miss_distance': {'astronomical': '0.154427104',
#                                             'kilometers': '23101965.82866848',
#                                             'lunar': '60.072143456',
#                                             'miles': '14354895.920565824'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '35259.6456975543',
#                                                 'kilometers_per_second': '9.7943460271',
#                                                 'miles_per_hour': '21908.9726280165'}},
#                          {'close_approach_date': '1993-06-22',
#                           'close_approach_date_full': '1993-Jun-22 05:31',
#                           'epoch_date_close_approach': 740727060000,
#                           'miss_distance': {'astronomical': '0.4405255913',
#                                             'kilometers': '65901690.138970531',
#                                             'lunar': '171.3644550157',
#                                             'miles': '40949411.4029180878'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '97954.0499986135',
#                                                 'kilometers_per_second': '27.2094583329',
#                                                 'miles_per_hour': '60864.8373449718'}},
#                          {'close_approach_date': '1999-10-03',
#                           'close_approach_date_full': '1999-Oct-03 13:19',
#                           'epoch_date_close_approach': 938956740000,
#                           'miss_distance': {'astronomical': '0.4725349562',
#                                             'kilometers': '70690222.948063294',
#                                             'lunar': '183.8160979618',
#                                             'miles': '43924867.7167456972'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '102528.4426623292',
#                                                 'kilometers_per_second': '28.4801229618',
#                                                 'miles_per_hour': '63707.1870531567'}},
#                          {'close_approach_date': '1999-10-29',
#                           'close_approach_date_full': '1999-Oct-29 15:39',
#                           'epoch_date_close_approach': 941211540000,
#                           'miss_distance': {'astronomical': '0.074908575',
#                                             'kilometers': '11206163.26473525',
#                                             'lunar': '29.139435675',
#                                             'miles': '6963186.96543645'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '41724.4219885332',
#                                                 'kilometers_per_second': '11.590117219',
#                                                 'miles_per_hour': '25925.9332072639'}},
#                          {'close_approach_date': '2000-10-27',
#                           'close_approach_date_full': '2000-Oct-27 01:04',
#                           'epoch_date_close_approach': 972608640000,
#                           'miss_distance': {'astronomical': '0.1236797907',
#                                             'kilometers': '18502233.250765809',
#                                             'lunar': '48.1114385823',
#                                             'miles': '11496754.6304298042'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '37729.767231342',
#                                                 'kilometers_per_second': '10.4804908976',
#                                                 'miles_per_hour': '23443.8100888303'}},
#                          {'close_approach_date': '2001-09-06',
#                           'close_approach_date_full': '2001-Sep-06 06:10',
#                           'epoch_date_close_approach': 999756600000,
#                           'miss_distance': {'astronomical': '0.4986078683',
#                                             'kilometers': '74590675.062920521',
#                                             'lunar': '193.9584607687',
#                                             'miles': '46348496.2757683498'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40794.7699659762',
#                                                 'kilometers_per_second': '11.3318805461',
#                                                 'miles_per_hour': '25348.2835935812'}},
#                          {'close_approach_date': '2002-02-02',
#                           'close_approach_date_full': '2002-Feb-02 07:53',
#                           'epoch_date_close_approach': 1012636380000,
#                           'miss_distance': {'astronomical': '0.4153844541',
#                                             'kilometers': '62140629.564472767',
#                                             'lunar': '161.5845526449',
#                                             'miles': '38612396.7307355046'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62397.0789982848',
#                                                 'kilometers_per_second': '17.332521944',
#                                                 'miles_per_hour': '38771.118336462'}},
#                          {'close_approach_date': '2003-06-11',
#                           'close_approach_date_full': '2003-Jun-11 04:21',
#                           'epoch_date_close_approach': 1055305260000,
#                           'miss_distance': {'astronomical': '0.2904388431',
#                                             'kilometers': '43449032.293024197',
#                                             'lunar': '112.9807099659',
#                                             'miles': '26997976.7540680386'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29640.5260813131',
#                                                 'kilometers_per_second': '8.233479467',
#                                                 'miles_per_hour': '18417.4702198026'}},
#                          {'close_approach_date': '2004-06-15',
#                           'close_approach_date_full': '2004-Jun-15 12:39',
#                           'epoch_date_close_approach': 1087303140000,
#                           'miss_distance': {'astronomical': '0.3035030487',
#                                             'kilometers': '45403409.624026269',
#                                             'lunar': '118.0626859443',
#                                             'miles': '28212370.5153657522'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82719.4586051552',
#                                                 'kilometers_per_second': '22.9776273903',
#                                                 'miles_per_hour': '51398.6547094088'}},
#                          {'close_approach_date': '2009-10-26',
#                           'close_approach_date_full': '2009-Oct-26 08:37',
#                           'epoch_date_close_approach': 1256546220000,
#                           'miss_distance': {'astronomical': '0.1488853945',
#                                             'kilometers': '22272937.891309715',
#                                             'lunar': '57.9164184605',
#                                             'miles': '13839761.847375467'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '41185.6927840609',
#                                                 'kilometers_per_second': '11.4404702178',
#                                                 'miles_per_hour': '25591.187830185'}},
#                          {'close_approach_date': '2011-10-24',
#                           'close_approach_date_full': '2011-Oct-24 08:12',
#                           'epoch_date_close_approach': 1319443920000,
#                           'miss_distance': {'astronomical': '0.0034000009',
#                                             'kilometers': '508632.892638083',
#                                             'lunar': '1.3226003501',
#                                             'miles': '316049.8240602254'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '50475.8049263633',
#                                                 'kilometers_per_second': '14.021056924',
#                                                 'miles_per_hour': '31363.7022332728'}},
#                          {'close_approach_date': '2011-10-24',
#                           'close_approach_date_full': '2011-Oct-24 14:26',
#                           'epoch_date_close_approach': 1319466360000,
#                           'miss_distance': {'astronomical': '0.0048669782',
#                                             'kilometers': '728089.572056434',
#                                             'lunar': '1.8932545198',
#                                             'miles': '452413.8813654292'},
#                           'orbiting_body': 'Moon',
#                           'relative_velocity': {'kilometers_per_hour': '48057.8452370816',
#                                                 'kilometers_per_second': '13.3494014547',
#                                                 'miles_per_hour': '29861.2761141189'}},
#                          {'close_approach_date': '2012-09-09',
#                           'close_approach_date_full': '2012-Sep-09 16:19',
#                           'epoch_date_close_approach': 1347207540000,
#                           'miss_distance': {'astronomical': '0.4891991421',
#                                             'kilometers': '73183149.663987327',
#                                             'lunar': '190.2984662769',
#                                             'miles': '45473900.5484140326'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40139.4643545161',
#                                                 'kilometers_per_second': '11.1498512096',
#                                                 'miles_per_hour': '24941.1021707269'}},
#                          {'close_approach_date': '2013-01-27',
#                           'close_approach_date_full': '2013-Jan-27 20:23',
#                           'epoch_date_close_approach': 1359318180000,
#                           'miss_distance': {'astronomical': '0.408190357',
#                                             'kilometers': '61064407.96173959',
#                                             'lunar': '158.786048873',
#                                             'miles': '37943663.636362742'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '60969.8694572788',
#                                                 'kilometers_per_second': '16.9360748492',
#                                                 'miles_per_hour': '37884.3058302741'}},
#                          {'close_approach_date': '2014-06-01',
#                           'close_approach_date_full': '2014-Jun-01 19:32',
#                           'epoch_date_close_approach': 1401651120000,
#                           'miss_distance': {'astronomical': '0.2556615087',
#                                             'kilometers': '38246417.142506469',
#                                             'lunar': '99.4523268843',
#                                             'miles': '23765221.6043845122'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28266.223998028',
#                                                 'kilometers_per_second': '7.8517288883',
#                                                 'miles_per_hour': '17563.5323503302'}},
#                          {'close_approach_date': '2015-06-19',
#                           'close_approach_date_full': '2015-Jun-19 17:01',
#                           'epoch_date_close_approach': 1434733260000,
#                           'miss_distance': {'astronomical': '0.4092978005',
#                                             'kilometers': '61230079.150484935',
#                                             'lunar': '159.2168443945',
#                                             'miles': '38046606.939504703'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '94424.6823265987',
#                                                 'kilometers_per_second': '26.2290784241',
#                                                 'miles_per_hour': '58671.8255267691'}},
#                          {'close_approach_date': '2021-10-19',
#                           'close_approach_date_full': '2021-Oct-19 18:10',
#                           'epoch_date_close_approach': 1634667000000,
#                           'miss_distance': {'astronomical': '0.0981156868',
#                                             'kilometers': '14677897.758867116',
#                                             'lunar': '38.1670021652',
#                                             'miles': '9120422.7477375608'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '61114.3682347681',
#                                                 'kilometers_per_second': '16.9762133985',
#                                                 'miles_per_hour': '37974.0917512091'}},
#                          {'close_approach_date': '2022-09-17',
#                           'close_approach_date_full': '2022-Sep-17 15:47',
#                           'epoch_date_close_approach': 1663429620000,
#                           'miss_distance': {'astronomical': '0.4509513876',
#                                             'kilometers': '67461367.058504412',
#                                             'lunar': '175.4200897764',
#                                             'miles': '41918549.7011764056'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '38368.0291145188',
#                                                 'kilometers_per_second': '10.6577858651',
#                                                 'miles_per_hour': '23840.4012017408'}},
#                          {'close_approach_date': '2023-01-16',
#                           'close_approach_date_full': '2023-Jan-16 05:01',
#                           'epoch_date_close_approach': 1673845260000,
#                           'miss_distance': {'astronomical': '0.394473478',
#                                             'kilometers': '59012392.08029186',
#                                             'lunar': '153.450182942',
#                                             'miles': '36668600.093113268'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57285.3210152015',
#                                                 'kilometers_per_second': '15.9125891709',
#                                                 'miles_per_hour': '35594.8707163623'}},
#                          {'close_approach_date': '2024-06-17',
#                           'close_approach_date_full': '2024-Jun-17 13:55',
#                           'epoch_date_close_approach': 1718632500000,
#                           'miss_distance': {'astronomical': '0.3422400937',
#                                             'kilometers': '51198389.046120419',
#                                             'lunar': '133.1313964493',
#                                             'miles': '31813203.7553990222'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '31728.3619731287',
#                                                 'kilometers_per_second': '8.8134338814',
#                                                 'miles_per_hour': '19714.7702493588'}},
#                          {'close_approach_date': '2025-06-14',
#                           'close_approach_date_full': '2025-Jun-14 07:47',
#                           'epoch_date_close_approach': 1749887220000,
#                           'miss_distance': {'astronomical': '0.3029281002',
#                                             'kilometers': '45317398.553066574',
#                                             'lunar': '117.8390309778',
#                                             'miles': '28158925.7141397612'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82582.5357389311',
#                                                 'kilometers_per_second': '22.9395932608',
#                                                 'miles_per_hour': '51313.5761651153'}},
#                          {'close_approach_date': '2031-10-14',
#                           'close_approach_date_full': '2031-Oct-14 11:30',
#                           'epoch_date_close_approach': 1949743800000,
#                           'miss_distance': {'astronomical': '0.2327006319',
#                                             'kilometers': '34811518.879894053',
#                                             'lunar': '90.5205458091',
#                                             'miles': '21630874.7949738114'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '75798.2075331794',
#                                                 'kilometers_per_second': '21.0550576481',
#                                                 'miles_per_hour': '47098.058453047'}},
#                          {'close_approach_date': '2032-09-28',
#                           'close_approach_date_full': '2032-Sep-28 12:04',
#                           'epoch_date_close_approach': 1979985840000,
#                           'miss_distance': {'astronomical': '0.383992935',
#                                             'kilometers': '57444525.17104845',
#                                             'lunar': '149.373251715',
#                                             'miles': '35694372.77123061'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '35179.3352379603',
#                                                 'kilometers_per_second': '9.7720375661',
#                                                 'miles_per_hour': '21859.0708316093'}},
#                          {'close_approach_date': '2033-10-29',
#                           'close_approach_date_full': '2033-Oct-29 21:05',
#                           'epoch_date_close_approach': 2014232700000,
#                           'miss_distance': {'astronomical': '0.0987134811',
#                                             'kilometers': '14767326.512845257',
#                                             'lunar': '38.3995441479',
#                                             'miles': '9175991.1987162666'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '39072.7237166626',
#                                                 'kilometers_per_second': '10.8535343657',
#                                                 'miles_per_hour': '24278.2710227229'}},
#                          {'close_approach_date': '2034-07-02',
#                           'close_approach_date_full': '2034-Jul-02 09:15',
#                           'epoch_date_close_approach': 2035444500000,
#                           'miss_distance': {'astronomical': '0.4235544432',
#                                             'kilometers': '63362842.531755984',
#                                             'lunar': '164.7626784048',
#                                             'miles': '39371844.6525372192'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '36010.4869754867',
#                                                 'kilometers_per_second': '10.0029130487',
#                                                 'miles_per_hour': '22375.5161987406'}},
#                          {'close_approach_date': '2035-06-08',
#                           'close_approach_date_full': '2035-Jun-08 12:34',
#                           'epoch_date_close_approach': 2064918840000,
#                           'miss_distance': {'astronomical': '0.1661829592',
#                                             'kilometers': '24860616.726616904',
#                                             'lunar': '64.6451711288',
#                                             'miles': '15447670.9159011152'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '67532.1707510233',
#                                                 'kilometers_per_second': '18.7589363197',
#                                                 'miles_per_hour': '41961.8646536011'}},
#                          {'close_approach_date': '2037-07-25',
#                           'close_approach_date_full': '2037-Jul-25 21:14',
#                           'epoch_date_close_approach': 2132169240000,
#                           'miss_distance': {'astronomical': '0.057964611',
#                                             'kilometers': '8671382.34097857',
#                                             'lunar': '22.548233679',
#                                             'miles': '5388147.134981466'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '44868.6815366531',
#                                                 'kilometers_per_second': '12.4635226491',
#                                                 'miles_per_hour': '27879.6538137054'}},
#                          {'close_approach_date': '2041-10-06',
#                           'close_approach_date_full': '2041-Oct-06 19:29',
#                           'epoch_date_close_approach': 2264700540000,
#                           'miss_distance': {'astronomical': '0.3913969739',
#                                             'kilometers': '58552153.619885593',
#                                             'lunar': '152.2534228471',
#                                             'miles': '36382621.1748354634'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '93273.77117628',
#                                                 'kilometers_per_second': '25.9093808823',
#                                                 'miles_per_hour': '57956.6940956169'}},
#                          {'close_approach_date': '2042-10-17',
#                           'close_approach_date_full': '2042-Oct-17 19:30',
#                           'epoch_date_close_approach': 2297187000000,
#                           'miss_distance': {'astronomical': '0.2677174402',
#                                             'kilometers': '40049958.815772374',
#                                             'lunar': '104.1420842378',
#                                             'miles': '24885890.4340478012'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30117.6215799224',
#                                                 'kilometers_per_second': '8.3660059944',
#                                                 'miles_per_hour': '18713.9188089245'}},
#                          {'close_approach_date': '2043-02-09',
#                           'close_approach_date_full': '2043-Feb-09 03:43',
#                           'epoch_date_close_approach': 2307066180000,
#                           'miss_distance': {'astronomical': '0.0409156456',
#                                             'kilometers': '6120893.431434872',
#                                             'lunar': '15.9161861384',
#                                             'miles': '3803346.8147583536'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '48778.0801505784',
#                                                 'kilometers_per_second': '13.5494667085',
#                                                 'miles_per_hour': '30308.8020802302'}},
#                          {'close_approach_date': '2044-02-26',
#                           'close_approach_date_full': '2044-Feb-26 12:45',
#                           'epoch_date_close_approach': 2340103500000,
#                           'miss_distance': {'astronomical': '0.4073616738',
#                                             'kilometers': '60940438.720114806',
#                                             'lunar': '158.4636911082',
#                                             'miles': '37866632.7215880828'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '60281.682606778',
#                                                 'kilometers_per_second': '16.7449118352',
#                                                 'miles_per_hour': '37456.6932841949'}},
#                          {'close_approach_date': '2044-07-14',
#                           'close_approach_date_full': '2044-Jul-14 22:01',
#                           'epoch_date_close_approach': 2352146460000,
#                           'miss_distance': {'astronomical': '0.4895527125',
#                                             'kilometers': '73236043.042722375',
#                                             'lunar': '190.4360051625',
#                                             'miles': '45506766.969923775'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '39423.9002507759',
#                                                 'kilometers_per_second': '10.951083403',
#                                                 'miles_per_hour': '24496.4784641557'}},
#                          {'close_approach_date': '2045-05-31',
#                           'close_approach_date_full': '2045-May-31 17:06',
#                           'epoch_date_close_approach': 2379863160000,
#                           'miss_distance': {'astronomical': '0.0452919039',
#                                             'kilometers': '6775572.351684693',
#                                             'lunar': '17.6185506171',
#                                             'miles': '4210145.4322990434'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '49503.8598705324',
#                                                 'kilometers_per_second': '13.7510721863',
#                                                 'miles_per_hour': '30759.7733734428'}},
#                          {'close_approach_date': '2048-08-24',
#                           'close_approach_date_full': '2048-Aug-24 08:13',
#                           'epoch_date_close_approach': 2481869580000,
#                           'miss_distance': {'astronomical': '0.0348592168',
#                                             'kilometers': '5214864.583148216',
#                                             'lunar': '13.5602353352',
#                                             'miles': '3240366.5941727408'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '50864.6474682714',
#                                                 'kilometers_per_second': '14.1290687412',
#                                                 'miles_per_hour': '31605.3138671601'}},
#                          {'close_approach_date': '2052-10-26',
#                           'close_approach_date_full': '2052-Oct-26 03:42',
#                           'epoch_date_close_approach': 2613526920000,
#                           'miss_distance': {'astronomical': '0.0758710511',
#                                             'kilometers': '11350147.639221157',
#                                             'lunar': '29.5138388779',
#                                             'miles': '7052654.7070676866'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42529.5714047706',
#                                                 'kilometers_per_second': '11.8137698347',
#                                                 'miles_per_hour': '26426.2217431476'}},
#                          {'close_approach_date': '2092-10-04',
#                           'close_approach_date_full': '2092-Oct-04 00:52',
#                           'epoch_date_close_approach': 3873919920000,
#                           'miss_distance': {'astronomical': '0.4564530392',
#                                             'kilometers': '68284402.419346504',
#                                             'lunar': '177.5602322488',
#                                             'miles': '42429960.1599855952'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '100614.5994345703',
#                                                 'kilometers_per_second': '27.9484998429',
#                                                 'miles_per_hour': '62517.999298664'}}],
#  'designation': '2011 UC64',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 51.289094295,
#                                  'estimated_diameter_min': 22.9371802696},
#                         'kilometers': {'estimated_diameter_max': 0.0156329154,
#                                        'estimated_diameter_min': 0.0069912523},
#                         'meters': {'estimated_diameter_max': 15.6329154409,
#                                    'estimated_diameter_min': 6.9912523225},
#                         'miles': {'estimated_diameter_max': 0.0097138403,
#                                   'estimated_diameter_min': 0.0043441614}},
#  'id': '3582523',
#  'is_potentially_hazardous_asteroid': False,
#  'is_sentry_object': True,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3582523?api_key=DEMO_KEY'},
#  'name': '(2011 UC64)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3582523',
#  'neo_reference_id': '3582523',
#  'orbital_data': {'aphelion_distance': '1.566887146481367',
#                   'ascending_node_longitude': '211.4492522596194',
#                   'data_arc_in_days': 2,
#                   'eccentricity': '.4626425919679889',
#                   'epoch_osculation': '2461000.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '2011-10-22',
#                   'inclination': '3.929622594993481',
#                   'jupiter_tisserand_invariant': '5.660',
#                   'last_observation_date': '2011-10-24',
#                   'mean_anomaly': '194.0627885477152',
#                   'mean_motion': '.8889039186856353',
#                   'minimum_orbit_intersection': '.00154331',
#                   'observations_used': 49,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2021-04-15 05:32:36',
#                   'orbit_id': '6',
#                   'orbit_uncertainty': '7',
#                   'orbital_period': '404.9931521646441',
#                   'perihelion_argument': '288.1341799724903',
#                   'perihelion_distance': '.5756556115182028',
#                   'perihelion_time': '2461187.176206465200',
#                   'semi_major_axis': '1.071271378999785'},
#  'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/3582523?api_key=DEMO_KEY'}

# %% [markdown]
# ## Exercise 1: Define a CloseApproach class
#
# Each NEO record comes with a list of `close_approach_data`, where each record in this list represents a single “close approach” to another orbiting body.
# * Develop a class named `CloseApproach` to represent a *single* close approach record.
# * State variables are
#     * orbiting body (`str`)
#     * approach date (`datetime` object!)
#     * miss distance (`float` in km, document it!)
#     * relative velocity (`float` in km/hr, ditto)
#
# * Operations must include:
#     * `__init__(self, ...)` method to initialize a new object with specific data values
#     * `__str__(self)` method to return a nicely formatted string representation of the object.
#
# Write a little code to test your new class.

# %%
class CloseApproach:
  """ CloseApproach class for representing a single close approach record """

  def __init__(self, orbiting_body:'str', approach_date:'datetime', miss_distance:'float', relative_velocity:'float'):
    """ Initialize a new object for given parameters with miss distance in km and relative velocty in km/hr """
    self.orbiting_body = orbiting_body
    self.approach_date = approach_date
    self.miss_distance = miss_distance
    self.relative_velocity = relative_velocity

  def __str__(self):
    """ Return a string representation of the close approach data """
    return f'orbiting body: {self.orbiting_body}, approach date: {self.approach_date}, miss distance: {self.miss_distance}, relative velocity: {self.relative_velocity}'

# %%
# Test CloseApproach class
ca = CloseApproach(orbiting_body = 'Mars', approach_date = '2200-05-24', miss_distance = 1495843.3943824, relative_velocity = 472847.2939285)

assert str(ca) == 'orbiting body: Mars, approach date: 2200-05-24, miss distance: 1495843.3943824, relative velocity: 472847.2939285'

# %% [markdown]
# ## Exercise 2: Factory function: get_close_approach
#
# We want to be able to construct CloseApproach objects easily from a data record returned from the NEO API.
#
# Write an "object factory" function...
#
#     def get_close_approach(record):
#         ...
#
# This function provides an easy way to create a `CloseApproach` instance.  It takes a dictionary for a single `close_approach_data` record, constructs and returns a `CloseApproach` object representing that same record.
# This kind of function is called a “Factory” because it handles the details of constructing an object from raw materials.
#
# Remember to convert each element from the data dictionary to the correct type (e.g., parse the date/time string into a `datetime` object).
# Add little code to test your new factory function.

# %%
# Ex. 2 your code here
def get_close_approach(record:'dict'):
  """ Return a CloseApproach object for a single close approach data record """
  return CloseApproach(
      orbiting_body = record['orbiting_body'],
      approach_date = datetime.strptime(record['close_approach_date'], '%Y-%m-%d'),
      miss_distance = float(record['miss_distance']),
      relative_velocity = float(record['relative_velocity'])
  )

# %%
# Test get_close_approach function
d = {'orbiting_body': 'Earth', 'close_approach_date': '2100-03-28', 'miss_distance': '29829328.29382938', 'relative_velocity': '2382.93849383'}
assert get_close_approach(d).orbiting_body == 'Earth'

# %% [markdown]
# ## Exercise 3:  Define an Asteroid class
#
# Define a simple Asteroid class with some basic state variables representing a single NEO.  Your Asteroid class should define at least 4 "state variables:”
# * id  (`int`)
# * name (`str`)
# * estimated_diameter (`float` in m)
# * is_potentially_hazardous (`bool`)
# * close_approaches (`list` of CloseApproach objects, default to empty list)
#
# Operations must include:
# * `__init__(self, ...)` method to initialize a new object with specific data values
# * `__str__(self)` method to return a nicely formatted string representation of the object.
#
# Write a little code to test you new class (just leave close_approaches as an empty list for now).

# %%
# Ex. 3 your code here
class Asteroid:
  """ Asteroid class for representing a single NEO """


  def __init__(self, id:'int', name:'str', estimated_diameter:'float', is_potentially_hazardous:'bool', close_approaches:'list' = []):
    self.id = id
    self.name = name
    self.estimated_diameter = estimated_diameter
    self.is_potentially_hazardous = is_potentially_hazardous
    self.close_approaches = close_approaches


  def __str__(self):
    return f"id: {self.id}, name: {self.name}, estimated diameter: {self.estimated_diameter}, is potentially hazardous: {self.is_potentially_hazardous}, close approaches: {self.close_approaches}"

  def get_closest_to_earth(self):
    """ Return CloseApproach object from asteroid representing its nearest to Earth """
    earth_objects = [neo for neo in self.close_approaches if neo.orbiting_body == 'Earth']
    closest_approach = earth_objects[0]
    for approach in earth_objects:
      if approach.miss_distance < closest_approach.miss_distance:
        closest_approach = approach
    return closest_approach

# %%
# Test Asteroid class
a = Asteroid(id = 19828293, name = 'Ceres', estimated_diameter = 239893829.2392938, is_potentially_hazardous = True, close_approaches = [])
assert str(a) == 'id: 19828293, name: Ceres, estimated diameter: 239893829.2392938, is potentially hazardous: True, close approaches: []'

# %% [markdown]
# ## Exercise 4: Asteroid factory
#
# Write a function that returns an Asteroid object just from the id for a single NEO.
#
#     def asteroid_from_neo(neo_id):
#         ...
#
# This factory function takes the `id` for a single NEO, fetches the NEO record from API, constructs and returns an Asteroid object representing that NEO.  *Hint*: I provided the code fetch a NEO from its `id` above.
#
# Every `Asteroid` should have a list of “close approaches”.
# *Hint*: use the `get_close_approach` factory you defined above to construct the required list of CloseApproach objects.
#
# Now add a new method to `Asteroid` class to return the `CloseApproach` object from the asteroid representing its nearest to **Earth**:
#
#     def nearest_miss(self):
#         ...
#
# Extend your test code to demonstrate these new features.

# %%
# Ex. 4 your test code for nearest_miss here
def asteroid_from_neo(neo_id):
  """ Return an Asteroid object representing a single NEO from it's id """
  neo = get_neo(neo_id)

  return Asteroid(
      id = neo['id'],
      name = neo['name'],
      estimated_diameter = float(neo['estimated_diameter']['meters']['estimated_diameter_max']),
      is_potentially_hazardous = neo['is_potentially_hazardous'],
      close_approaches = neo['close_approach_data']
  )

# %%
asteroid_from_neo(3797409)
# Out:
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3797409?api_key=DEMO_KEY'}, 'id': '3797409', 'neo_reference_id': '3797409', 'name': '(2018 AV)', 'designation': '2018 AV', 'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3797409', 'absolute_magnitude_h': 23.53, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0523064176, 'estimated_diameter_max': 0.1169607054}, 'meters': {'estimated_diameter_min': 52.3064175804, 'estimated_diameter_max': 116.9607053693}, 'miles': {'estimated_diameter_min': 0.032501691, 'estimated_diameter_max': 0.0726759905}, 'feet': {'estimated_diameter_min': 171.6089870545, 'estimated_diameter_max': 383.7293606038}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [], 'orbital_data': {'orbit_id': '8', 'orbit_determination_date': '2022-12-26 07:02:28', 'first_observation_date': '2017-11-17', 'last_observation_date': '2022-12-25', 'data_arc_in_days': 1864, 'observations_used': 37, 'orbit_uncertainty': '1', 'minimum_orbit_intersection': '.152446', 'jupiter_tisserand_invariant': '4.735', 'epoch_osculation': '2461000.5', 'eccentricity': '.1945405252179211', 'semi_major_axis': '1.397089910471182', 'inclination': '6.065358081141168', 'ascending_node_longitude': '241.9599511222998', 'orbital_period': '603.1633731029311', 'perihelion_distance': '1.12529930551146', 'perihelion_argument': '216.652226202787', 'aphelion_distance': '1.668880515430904', 'perihelion_time': '2461141.409909722939', 'mean_anomaly': '275.8974669842871', 'mean_motion': '.5968532176415248', 'equinox': 'J2000', 'orbit_class': {'orbit_class_type': 'AMO', 'orbit_class_description': 'Near-Earth asteroid orbits similar to that of 1221 Amor', 'orbit_class_range': '1.017 AU < q (perihelion) < 1.3 AU'}}, 'is_sentry_object': False}

# %% [markdown]
# ## Challenge - Take your skills to the next level...
# ### Exercise 5: develop a useful analysis / data product
#
#  With these data structures in place, we can now start answering all kinds of interesting questions about a single Asteroid or a set of Asteroids.
# Here’s a couple ideas to try:
#
# * write a **function** named `most_dangerous_approach`, that takes a date range and returns a single “potentially hazardous” Asteroid object that makes the closest approach to Earth within that range.  Your algorithm will ultimately need to:
#     * grab the list of NEO’s for the given date range;
#     * use a list comprehension to build the list of Asteroid objects for the NEO’s returned
#     * use a list comprehension to filter  potentially hazardous Asteroids only;
#     * use a list comprehension to map each Asteroid to its  nearest_miss
#     * apply Python’s min function to identify the Asteroid with the nearest_miss
#
# You may want to decompose some of these steps into smaller functions.
# * add a method to the Asteroid class, `estimated_mass`, that computes an estimate of the Asteroid’s mass based on its diameter.  This is a model – state your assumptions.
# * add a method to the `CloseApproach` class, `impact_force`,  that estimates the force of impact if the Asteroid hit the orbiting object.  Again, this is a model, state your assumptions.

# %%
# Ex. 5 (challenge) your code here
